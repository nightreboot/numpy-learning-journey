# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series in pandas

# %%
list=[10,20,30,40]
arr=np.array([10,20,30,40])
dics={1:10,2:20,3:30,4:40}
labels=['a','b','c','d']

# %%
pd.Series(list)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
pd.Series(list,index=labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
pd.Series(dics)
# Out:
# 1    10
# 2    20
# 3    30
# 4    40
# dtype: int64
