# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Creating a dataframe

# %%
data= {
    "Name":["Raj","Rahul","teena","Meena","Sona"],
    "Age" :[20,30,40,18,16],
    "City":["Delhi","Mumbai","gujrat","Tamilnadu","mumbai"],
    "Salary":[20000,18000,21000,100000,15000]
}
df2=pd.DataFrame(data)
df2
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  teena   40     gujrat   21000
# 3  Meena   18  Tamilnadu  100000
# 4   Sona   16     mumbai   15000

# %%
data=[
    ["Raj",20,"Delhi",20000],
    ['Rahul',30,"Mumbai",18000],
    ["Teena",40,"Gujrat",21000],
    ["Meena",18,"Tamilnadu",100000]
]
colomns=['Name','Age','City','Salary']
df=pd.DataFrame(data=data,columns=colomns)

# %% [markdown]
# ### Selecting And indexing of columns

# %%
df["Name"]
# Out:
# 0      Raj
# 1    Rahul
# 2    Teena
# 3    Meena
# Name: Name, dtype: object

# %%
df[['Name','Age']]     ## We Can seclect multiple columns
# Out:
#     Name  Age
# 0    Raj   20
# 1  Rahul   30
# 2  Teena   40
# 3  Meena   18

# %% [markdown]
# ### Creating a new Columns

# %%
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df["Designation"]=['doctor','engineer','sainik','police']
df
# Out:
#     Name  Age       City  Salary Designation
# 0    Raj   20      Delhi   20000      doctor
# 1  Rahul   30     Mumbai   18000    engineer
# 2  Teena   40     Gujrat   21000      sainik
# 3  Meena   18  Tamilnadu  100000      police

# %% [markdown]
# ###  Removind Columns

# %%
df
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df.drop('Salary',axis=1)        ## paased me copy of the data frame   if we do use of inplace
# Out:
#     Name  Age       City
# 0    Raj   20      Delhi
# 1  Rahul   30     Mumbai
# 2  Teena   40     Gujrat
# 3  Meena   18  Tamilnadu

# %%
df
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df.drop(["Name","Age"], axis=1)         ## we can remove multiple data from col
# Out:
#         City  Salary
# 0      Delhi   20000
# 1     Mumbai   18000
# 2     Gujrat   21000
# 3  Tamilnadu  100000

# %%
df
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df.drop([0],axis=0)           ## we can drop of rows also
# Out:
#     Name  Age       City  Salary
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %% [markdown]
# ### Selecting Of Row

# %%
df.loc[0]
# Out:
# Name        Raj
# Age          20
# City      Delhi
# Salary    20000
# Name: 0, dtype: object

# %%
df.loc[[2,3]]           ### here have an iloc[] they work same as loc
# Out:
#     Name  Age       City  Salary
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %% [markdown]
# ### Selecting Subsets of Rows and Columns

# %%
df
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df.loc[[2,3]][["City","Salary"]]
# df.loc[[2,3]][["Name"]]
# Out:
#         City  Salary
# 2     Gujrat   21000
# 3  Tamilnadu  100000

# %% [markdown]
# ### Conditional Selection

# %%
df[(df['Age']>=30 )& (df["City"]=="Gujrat")]
# Out:
#     Name  Age    City  Salary
# 2  Teena   40  Gujrat   21000

# %%
df[df['Age']>=30 ]
# Out:
#     Name  Age    City  Salary
# 1  Rahul   30  Mumbai   18000
# 2  Teena   40  Gujrat   21000

# %%
df[df['Salary']>20000]
# Out:
#     Name  Age       City  Salary
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df
# Out:
#     Name  Age       City  Salary
# 0    Raj   20      Delhi   20000
# 1  Rahul   30     Mumbai   18000
# 2  Teena   40     Gujrat   21000
# 3  Meena   18  Tamilnadu  100000

# %%
df[['Salary','Age','Name']]
# Out:
#    Salary  Age   Name
# 0   20000   20    Raj
# 1   18000   30  Rahul
# 2   21000   40  Teena
# 3  100000   18  Meena

# %%
# Out:
#     Name  Age    City  Salary
# 1  Rahul   30  Mumbai   18000
